# %%
import numpy as np

x=np.ones([100, 10,5])

print(x+x/2)
print (np.shape(x))
# Out:
# [[[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]]
#
#  [[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]]
#
#  [[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]]
#
#  ...
#
#  [[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]]
#
#  [[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]]
#
#  [[1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
#   ...
#   [1.5 1.5 1.5 1.5 1.5]
#   [1.5 1.5 1.5 1.5 1.5]
# ...
